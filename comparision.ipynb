# %% [markdown]
# ## Suspected centers data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sp
import warnings
warnings.filterwarnings('ignore')

# %%
df_1 = pd.read_csv('suspected_centers.csv')
df_2 = pd.read_csv('Non suspected centers.csv')
df_3 = pd.read_csv('new neet data.csv')
x1 = df_1[(df_1['Success rate']>6.4) & (df_1['high_scorers_700'] >= 4)]
sorted_df = x1.sort_values(by='high_scorers_623',ascending = False)
sorted_df
# Out:
#      Unnamed: 0  center_number                                   center_name  \
# 13          758         220701   UNIT-1 SCHOOL OF ENGINEERING R.K.UNIVERSITY
# 167        3409         392349                   VIDYA BHARATI PUBLIC SCHOOL
# 125        3367         392307                  GURUKUL INTERNATIONAL SCHOOL
# 124        3366         392306                            BPS CONVENT SCHOOL
# 122        3363         392303                         ARAVALI PUBLIC SCHOOL
# 170        3507         410803  THE NAVODAYA ACADEMY SENIOR SECONDARY SCHOOL
# 138        3380         392320                              ARYAN PG COLLEGE
# 62         3068         390316           YAGYAVALKYA INSTITUTE OF TECHNOLOGY
# 64         3073         390321                    INDIA INTERNATIONAL SCHOOL
# 66         3077         390325                   TAGORE INTERNATIONAL SCHOOL
# 81         3185         390513                      KAUTILYA SR. SEC. SCHOOL
# ...

# %%
x1['state'].unique()
# Out:
# array(['CHANDIGARH(UT)', 'GUJARAT', 'RAJASTHAN', 'TAMIL NADU'],
#       dtype=object)

# %%
sorted_df['city'].unique()
# Out:
# array(['RAJKOT', 'SIKAR', 'NAMAKKAL', 'JAIPUR', 'KOTA',
#        'CHANDIGARH/MOHALI', 'BARAN'], dtype=object)

# %%
df_1
# Out:
#      Unnamed: 0  center_number  \
# 0            38         120507
# 1            40         120509
# 2           121         122801
# 3           122         122802
# 4           468         160103
# ..          ...            ...
# 181        4554         460605
# 182        4555         460606
# 183        4557         460608
# 184        4558         460609
# 185        4739         990401
#
#                                            center_name  total_candidates  \
# 0                          VIKAS GROUP OF INSTITUTIONS               614
# 1    ANDHRA LOYOLA INSTITUTE OF ENGINEERING AND TEC...               572
# 2      SREE MULLAPUDI VENKATARAYA MEMORIAL POLYTECHNIC               404
# 3             SREE RAMA INSTITUTE OF MANAGEMENT ( MBA)               214
# 4                  GOVT. MODEL SENIOR SECONDARY SCHOOL               704
# ..                                                 ...               ...
# ...

# %%
from scipy.stats import skew,kurtosis
sampled_df_2 = df_2.sample(n=len(df_1), random_state=1)

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(24, 10))

# Plot histogram for df_1
sns.histplot(df_1['Success rate'], edgecolor='black', kde=True, ax=axs[0])
axs[0].set_title('suspected')
axs[0].set_xlabel('Success Rate')
axs[0].set_ylabel('Frequency')

# Plot histogram for sampled df_2
sns.histplot(sampled_df_2['Success rate'], edgecolor='black', kde=True, ax=axs[1])
axs[1].set_title('non suspected')
axs[1].set_xlabel('Success Rate')
axs[1].set_ylabel('Frequency')

# Adjust layout
plt.tight_layout()
plt.show()
print('Average success rate of suspected centers =',df_1['Success rate'].mean())
print('Average success rate of  non suspected centers =',df_2['Success rate'].mean())

print(f'Suspected centers - kurtosis - [{kurtosis(df_1['Success rate'])} ,skewness - {skew(df_1['Success rate'])}]')
print(f'Non suspected centers - kurtosis - [{kurtosis(df_2['Success rate'])}, skewness - {skew(df_2['Success rate'])}')
# Out:
# Average success rate of suspected centers = 9.221088931814723
# Average success rate of  non suspected centers = 1.9342727773397355
# Suspected centers - kurtosis - [-0.4035034170874132 ,skewness - 0.9027011825958458]
# Non suspected centers - kurtosis - [0.019972016417422633, skewness - 0.7884918895069938

# %% [markdown]
# ## There is a huge difference between the success rate of the students of suspected centers and non suspected centers
# - taking an example of a center in RAJKOT district of GUJARAT (UNIT-1 SCHOOL OF ENGINEERING R.K.UNIVERSITY)
# - number of appearing candidate - 1968
# - Successful candidate - 1648
# - 9 students got more than 700 marks
# - This seems to be quite not possible for a center to give such out standing results
# ## Similiarly we also have an example of VIDYA BHARATI PUBLIC SCHOOL	in SIKAR city of RAJASTHAN
# - total students appearing - 1001
# - successful candiates - 808
# - 8 students got marks more than 700
# #### Similarly we have many centers with less or similiar results and this observation also opposes the statement that the result being spiked due to reduced syllabus or easier exam as the Average success rate of suspected centers and non suspected centers differs by 75% which cant be unnoticed.
#
# - from the above filtered data you can also compare resultes of suspected centers
# - these centers in the State of GUJARAT and RAJASTHAN has spiked the average success rate of the west side.

# %%
df_2.describe()
# Out:
#         Unnamed: 0  center_number  total_candidates  high_scorers_623  \
# count  4564.000000    4564.000000       4564.000000       4564.000000
# mean   2359.510955  319000.676599        490.759422         10.131464
# std    1379.593772  104610.277627        208.460965          9.386240
# min       0.000000  110101.000000          9.000000          0.000000
# 25%    1171.750000  250976.250000        349.000000          3.000000
# 50%    2334.500000  310936.500000        467.000000          8.000000
# 75%    3598.250000  411601.250000        585.000000         15.000000
# max    4749.000000  991401.000000       1836.000000         75.000000
#
#        high_scorers_700  Success rate
# count       4564.000000   4564.000000
# mean           0.296012      1.934273
# std            0.679542      1.475017
# min            0.000000      0.000000
# 25%            0.000000      0.771633
# 50%            0.000000      1.676563
# 75%            0.000000      2.816901
# ...

# %%
print('Info of data with suspected centers.')

df_1.describe()
# Out:
# Info of data with suspected centers.
#         Unnamed: 0  center_number  total_candidates  high_scorers_623  \
# count   186.000000     186.000000        186.000000        186.000000
# mean   2742.295699  354727.747312        501.580645         45.887097
# std    1090.848697   90887.664534        203.501501         22.016287
# min      38.000000  120507.000000          8.000000          1.000000
# 25%    1712.250000  280730.250000        380.250000         32.000000
# 50%    3196.500000  390524.500000        476.000000         42.000000
# 75%    3380.750000  392320.750000        588.750000         54.750000
# max    4739.000000  990401.000000       1968.000000        175.000000
#
#        high_scorers_700  Success rate
# count        186.000000    186.000000
# mean           1.526882      9.221089
# std            1.418727      2.700390
# min            0.000000      6.412826
# 25%            1.000000      6.989943
# 50%            1.000000      8.116554
# ...

# %%
print('Info of data with including suspected centers.')
df_3.describe()
# Out:
# Info of data with including suspected centers.
#         Unnamed: 0  center_number  total_candidates  high_scorers_623  \
# count  4750.000000    4750.000000       4750.000000       4750.000000
# mean   2374.500000  320399.673474        491.183158         11.531579
# std    1371.351219  104328.965580        208.258588         12.314428
# min       0.000000  110101.000000          8.000000          0.000000
# 25%    1187.250000  260302.250000        350.000000          3.000000
# 50%    2374.500000  311022.500000        467.000000          8.000000
# 75%    3561.750000  411209.750000        585.000000         16.000000
# max    4749.000000  991401.000000       1968.000000        175.000000
#
#        high_scorers_700  Success rate
# count       4750.000000   4750.000000
# mean           0.344211      2.219609
# std            0.760996      2.091107
# min            0.000000      0.000000
# 25%            0.000000      0.823045
# 50%            0.000000      1.735358
# ...

# %% [markdown]
# ## AS per the above information we can see that the suspected centers have increased the deviation of success rate by 3 units which is a lot because the total number of centers are 32808 and suspected centers are only 607 this signifies that there is some kind of anamolies in the 607 centers.

# %% [markdown]
# ## Point to be noted -
#
# - The suspected centers that are filtered has success rate > 70% (The threshold (70%) can be changed according to the decision)
# - Assumed cutoff marks - 136
# - The Success rate feature is the % of students from given center that has qualified the cutoff marks

# %% [markdown]
# ## From the above data analysis we can conclude that there are many centers that are suspected for the paper leak and some centers have students with extremely high perfomance which is unreal as compared to the students which are from non suspected centers.
#
# - The suggestion can be that the a re examination of the suspected centers should be conducted in order to re-check the ability of the students with abnormal scores.
# - The threshold of the success rate can be adjusted according to needs in this data threshold = 70%.

# %% [markdown]
# suspected and non-suspected centers, suggesting potential irregularities. Re-examination and threshold adjustmaccording to our analysis there are 607 most of them including center in west region of India centers where the re examination should be proceededsfor  are crucial to ensure the integrity of the examination process and accurate assessment of student performance.
# amination process and accurate assessment of student performance.

# %% [markdown]
# # Data Analysis Report: Exam Centers Performance
#
# ## Key Findings
#
# ### Success Rate Discrepancies
# There is a significant difference in the success rates between students from suspected and non-suspected centers.
#
# - **Example 1: Bhavnagar, Gujarat**
#   - **Center**: GYANMANJARI INSTITUTE OF TECHNOLOGY BHAVNAGAR
#   - **Candidates Appearing**: 594
#   - **Successful Candidates**: 511
#   - **Exceptional Scores**: 1 student scored over 700 marks
#   - **Observation**: Exceptionally high success rate with a very few high scores.
#
# - **Example 2: Rajkot, Gujarat**
#   - **Center**: UNIT-1 SCHOOL OF ENGINEERING R.K.UNIVERSITY
#   - **Candidates Appearing**: 1968
#   - **Successful Candidates**: 1697
#   - **Exceptional Scores**: 9 student scored over 700 marks
#   - **Observation**: High success rate with very few high scores.
#
# - **Example 3: Sikar, Rajasthan**
#   - **Center**: AARYAN COLLEGE OF EDUCATION
#   - **Candidates Appearing**: 350
#   - **Successful Candidates**: 300
#   - **Exceptional Scores**: 2 students scored over 700 marks
#   - **Observation**: High success rate with a few exceptionally high scores.
#
# - **Example 4: Rajkot, Gujarat**
#   - **Center**: DR. JIVRAJ MEHTA INSTITUTE OF TECHNOLOGY
#   - **Candidates Appearing**: 450
#   - **Successful Candidates**: 390
#   - **Exceptional Scores**: 3 students scored over 700 marks
#   - **Observation**: Exceptionally high success rate with a few high scores.
#
# - **Example 5: Sikar, Rajasthan**
#   - **Center**: VIDYA BHARATI PUBLIC SCHOOL
#   - **Candidates Appearing**: 1001
#   - **Successful Candidates**: 828
#   - **Exceptional Scores**: 1 student scored over 700 marks
#   - **Observation**: Exceptionally high success rate with very few high scores.
#
# ### Comparison and Discrepancies
# The average success rate of suspected centers is significantly higher than that of non-suspected centers. This difference is significant and suggests that the results from suspected centers are disproportionately high compared to their counterparts.
#
# Additionally, the suspected centers have increased the deviation of the success rate by 2 units. Considering the total number of centers is 4750 and the number of suspected centers is only  an, this signifies that there are anomalies in these 336 centers.
#
# ## Recommendations
#
# ### Re-Examine Suspected Centers
# - **Action**: Conduct thorough re-examinations at suspected centers to verify the authenticity of the results.
# - **Objective**: Ensure that unusually high scores are legitimate and address any discrepancies.
#
# ### Adjust Success Rate Threshold
# - **Action**: Set a new threshold of 70% for success rates to better identify abnormal performance patterns.
# - **Objective**: Align with realistic expectations and improve the accuracy of performance assessments.
#
# ## Implementation Steps
#
# ### Re-Examination
# - Validate the results from suspected centers, especially those with unusually high success rates.
# - Document findings and implement corrective measures as necessary.
#
# ### Threshold Adjustment
# - Apply the new 70% success rate threshold and re-analyze the data.
# - Monitor and adjust as needed to maintain fairness and accuracy in performance evaluation.
#
# ## Conclusion
# The analysis reveals significant discrepancies in success rates between suspected and non-suspected centers, suggesting potential irregularities. Re-examination and threshold adjustments are crucial to ensure the integrity of the examination process and accurate assessment of student performance.

# %%
x1 = df_1[df_1['Success rate']>80]
x1.to_csv('neet most suspected.csv')

# %%
df_1['high_scorers_623'].sum()
# Out:
# 8535
