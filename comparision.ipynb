# %% [markdown]
# ## Suspected centers data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sp

# %%
df_1 = pd.read_csv('suspected_centers.csv')
df_2 = pd.read_csv('Non suspected centers.csv')
df_3 = pd.read_csv('new neet data.csv')
df_1[df_1['Success rate']>85]
# Out:
#      Unnamed: 0                                        center_name  \
# 22          139  AMARJYOTI SARASWATI INTERNATIONAL SCHOOL KALVIBID
# 42         1281                                   ARYAN PG COLLEGE
# 44         1287                                       ASHA ACADEMY
# 74         1476                 BHARTIYA MAHILA P.G. MAHAVIDYALAYA
# 76         1489                          BHASHYAM(E.M) HIGH SCHOOL
# 99         1851                               CHITTURI HIGH SCHOOL
# 108        2037    D.A.V. PUBLIC SHIKSHAN SANSTHAN SR. SEC. SCHOOL
# 111        2051                                DANTA MAHAVIDHALAYA
# 133       26100                        DELHI PUBLIC SCHOOL, REWARI
# 189       26669      GYANMANJARI INSTITUTE OF TECHNOLOGY BHAVNAGAR
# 190       26670                             GYANMANJARI VIDHYAPITH
# 238       27482                 KENDRIYA VIDYALAYA NO.1 VIJAYAWADA
# 245       27523                           KENDRIYA VIDYALAYA SIKAR
# 253       27623  KVSR SIDDHARTHA COLLEGE OF PHARMACEUTICAL SCIE...
# 288       28026                         MAHATMA GANDHI INT. SCHOOL
# 289       28027                        MAHATMA GANDHI P.G. COLLEGE
# 314       28281                       MODY INSTITUTE OF TECHNOLOGY
# 325       28423                          NAND VIDYA NIKETAN SCHOOL
# 337       28521           NEW CENTRAL ACADEMY CHHAWANI NEEMKATHANA
# 354       28667  PALADUGU PARVATHI DEVI COLLEGE OF ENGINEERING ...
# 357       28697       PINK PEARL SHIKSHAN SANSTHAN SR. SEC. SCHOOL
# 365       30631    PODAR INTERNATIONAL SCHOOL VARTEJ BHAVNAGAR GUJ
# 367       30652                          POLKAJI SHIKSHAN SANSTHAN
# 413       31307                        SANSKAR BALIKA P.G. COLLEGE
# 422       31397                               SARTHI VIDHYA SANKUL
# 426       31405                          SARVODAYA SR. SEC. SCHOOL
# 428       31416                      SATYAM PUBLIC SR. SEC. SCHOOL
# 433       31511                             SEM SCHOOL NEEMKATHANA
# 438       31541                                  SGR PUBLIC SCHOOL
# 450       31638  SHREE GYANMANJARI SECONDARY AND HIGHER SECONDA...
# 452       31651           SHREE SAHAJANAND INSTITUTE OF MANAGEMENT
# 455       31662               SHREE VIDHYADHISH SEC.& H.SCE SCHOOL
# 456       31663                   SHREE VISHUDDHANAND VIDHYAMANDIR
# 460       31671                       SHRI ARJUNRAM MAHAVIDHYALAYA
# 461       31673                                SHRI BALAJI COLLEGE
# 462       31676                       SHRI BHAGWANDAS TODI COLLEGE
# 468       31725    SHRI MANGAL CHAND DIDWANIYA VIDYA MANDIR (CBSE)
# 469       31726    SHRI MANGAL CHAND DIDWANIYA VIDYA MANDIR (RBSE)
# 474       31787                         SILVER BELLS PUBLIC SCHOOL
# 481       31835                   SMT M S LAKHANI KANYA VIDHYALAYA
# 484       31857                                 SOBHASARIA COLLEGE
# 485       31858                   SOBHASARIA GROUP OF INSTITUTIONS
# 502       32006                        SRI VIJNAN VIHARA EM SCHOOL
# 535       32343                SUNRISE INTERNATIONAL PUBLIC SCHOOL
# 539       32359              SVP SHIKSHAN AVAM ANUSANDHAN SANSTHAN
# 541       32367                    SWAMI NITYANAND SR. SEC. SCHOOL
# 544       32395                                TAGORE P.G. COLLEGE
# 554       32477                             THE KPES ENGLISH CHOOL
# 568       32558        UNIT-1 SCHOOL OF ENGINEERING R.K.UNIVERSITY
# 579       32597                                 VARDA SMART SCHOOL
# 585       32640                        VIDYA BHARATI PUBLIC SCHOOL
# 588       32650                      VIDYA NIKETAN SR. SEC. SCHOOL
# 596       32701        VIKAS COLLEGE OF ENGINEERING AND TECHNOLOGY
# 597       32702                        VIKAS GROUP OF INSTITUTIONS
# 598       32714                            VINAYAK SR. SEC. SCHOOL
# 604       32788                        YASH PUBLIC SR. SEC. SCHOOL
#
#      total_candidates  high_scorers_137         state_y      city_y  \
# 22                359               311         GUJARAT   BHAVNAGAR
# 42                501               433       RAJASTHAN       SIKAR
# 44                355               302       RAJASTHAN       SIKAR
# 74                500               433       RAJASTHAN       SIKAR
# 76                499               440  ANDHRA PRADESH  VIJAYAWADA
# 99                503               430  ANDHRA PRADESH  VIJAYAWADA
# 108               502               432       RAJASTHAN       SIKAR
# 111               425               371       RAJASTHAN       SIKAR
# 133               264               233         HARYANA      REWARI
# 189               594               530         GUJARAT   BHAVNAGAR
# 190               357               320         GUJARAT   BHAVNAGAR
# 238               355               302  ANDHRA PRADESH  VIJAYAWADA
# 245               474               403       RAJASTHAN       SIKAR
# 253               402               359  ANDHRA PRADESH  VIJAYAWADA
# 288               703               605       RAJASTHAN       SIKAR
# 289               713               619       RAJASTHAN       SIKAR
# 314               668               578       RAJASTHAN       SIKAR
# 325               935               795         GUJARAT    JAMNAGAR
# 337               351               307       RAJASTHAN       SIKAR
# 354               613               535  ANDHRA PRADESH  VIJAYAWADA
# 357               502               433       RAJASTHAN       SIKAR
# 365               216               186         GUJARAT   BHAVNAGAR
# 367               429               365       RAJASTHAN       SIKAR
# 413               429               378       RAJASTHAN       SIKAR
# 422               334               294         GUJARAT   BHAVNAGAR
# 426               479               411       RAJASTHAN        KOTA
# 428               428               376       RAJASTHAN       SIKAR
# 433               474               406       RAJASTHAN       SIKAR
# 438               447               394       RAJASTHAN       SIKAR
# 450               477               414         GUJARAT   BHAVNAGAR
# 452               308               267         GUJARAT   BHAVNAGAR
# 455               479               414         GUJARAT   BHAVNAGAR
# 456               236               209         GUJARAT   BHAVNAGAR
# 460               404               358       RAJASTHAN       SIKAR
# 461               716               623       RAJASTHAN       SIKAR
# 462               597               529       RAJASTHAN       SIKAR
# 468               716               616       RAJASTHAN       SIKAR
# 469               574               492       RAJASTHAN       SIKAR
# 474               359               312         GUJARAT   BHAVNAGAR
# 481               240               205         GUJARAT   BHAVNAGAR
# 484               503               433       RAJASTHAN       SIKAR
# 485               502               436       RAJASTHAN       SIKAR
# 502               498               446  ANDHRA PRADESH  VIJAYAWADA
# 535               592               512       RAJASTHAN       SIKAR
# 539               477               421       RAJASTHAN       SIKAR
# 541               475               407       RAJASTHAN       SIKAR
# 544               356               306       RAJASTHAN       SIKAR
# 554               382               328         GUJARAT   BHAVNAGAR
# 568              1968              1732         GUJARAT      RAJKOT
# 579               714               613       RAJASTHAN       SIKAR
# 585              1001               853       RAJASTHAN       SIKAR
# 588               471               402       RAJASTHAN       SIKAR
# 596               477               409  ANDHRA PRADESH  VIJAYAWADA
# 597               614               533  ANDHRA PRADESH  VIJAYAWADA
# 598               476               414       RAJASTHAN       SIKAR
# 604               358               305       RAJASTHAN       SIKAR
#
#      high_scorers_500  high_scorers_700  Success rate
# 22                 65                 0     86.629526
# 42                162                 5     86.427146
# 44                124                 2     85.070423
# 74                147                 3     86.600000
# 76                119                 1     88.176353
# 99                124                 2     85.487078
# 108               170                 1     86.055777
# 111               142                 2     87.294118
# 133               108                 1     88.257576
# 189               171                 1     89.225589
# 190                77                 0     89.635854
# 238                87                 1     85.070423
# 245               149                 1     85.021097
# 253                92                 2     89.303483
# 288               230                 3     86.059744
# 289               230                 2     86.816269
# 314               219                 3     86.526946
# 325               192                 1     85.026738
# 337               126                 1     87.464387
# 354               137                 1     87.275693
# 357               175                 1     86.254980
# 365                46                 0     86.111111
# 367               133                 2     85.081585
# 413               158                 1     88.111888
# 422                77                 0     88.023952
# 426                99                 2     85.803758
# 428               143                 3     87.850467
# 433               160                 2     85.654008
# 438               148                 2     88.143177
# 450               104                 0     86.792453
# 452                64                 0     86.688312
# 455                98                 0     86.430063
# 456                46                 0     88.559322
# 460               138                 0     88.613861
# 461               233                 3     87.011173
# 462               202                 2     88.609715
# 468               230                 2     86.033520
# 469               200                 3     85.714286
# 474                67                 0     86.908078
# 481                49                 0     85.416667
# 484               166                 1     86.083499
# 485               173                 1     86.852590
# 502               120                 1     89.558233
# 535               198                 3     86.486486
# 539               165                 1     88.259958
# 541               166                 2     85.684211
# 544               118                 3     85.955056
# 554                66                 0     85.863874
# 568               594                 9     88.008130
# 579               242                 3     85.854342
# 585               316                 8     85.214785
# 588               142                 2     85.350318
# 596               106                 1     85.744235
# 597               146                 3     86.807818
# 598               157                 1     86.974790
# 604               116                 3     85.195531

# %%
sampled_df_2 = df_2.sample(n=len(df_1), random_state=1)

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(24, 10))

# Plot histogram for df_1
sns.histplot(df_1['Success rate'], edgecolor='black', kde=True, ax=axs[0])
axs[0].set_title('Histogram for Dataset 1')
axs[0].set_xlabel('Success Rate')
axs[0].set_ylabel('Frequency')

# Plot histogram for sampled df_2
sns.histplot(sampled_df_2['Success rate'], edgecolor='black', kde=True, ax=axs[1])
axs[1].set_title('Histogram for Sampled Dataset 2')
axs[1].set_xlabel('Success Rate')
axs[1].set_ylabel('Frequency')

# Adjust layout
plt.tight_layout()
plt.show()
print('Average success rate of suspected centers =',df_1['Success rate'].mean())
print('Average success rate of  non suspected centers =',df_2['Success rate'].mean())
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Average success rate of suspected centers = 75.98880160852326
# Average success rate of  non suspected centers = 7.986031489385388

# %% [markdown]
# ## There is a huge difference between the success rate of the students of suspected centers and non suspected centers
# - taking an example of a center in RAJKOT district of GUJARAT (UNIT-1 SCHOOL OF ENGINEERING R.K.UNIVERSITY)
# - number of appearing candidate - 1968
# - Successful candidate - 1732
# - 9 students got more than 700 marks
# - This seems to be quite not possible for a center to give such out standing results
# ## Similiarly we also have an example of VIDYA BHARATI PUBLIC SCHOOL	in SIKAR city of RAJASTHAN
# - total students appearing - 10001
# - successful candiates - 853
# - success rate - 85%
# - 8 students got marks more than 700
# #### Similarly we have many centers with less or similiar results and this observation also opposes the statement that the result being spiked due to reduced syllabus or easier exam as the Average success rate of suspected centers and non suspected centers differs by 75% which cant be unnoticed.
#
# - from the above filtered data you can also compare resultes of suspected centers
# - these centers in the State of GUJARAT and RAJASTHAN has spiked the average success rate of the west side.

# %%
df_1.describe()
# Out:
#          Unnamed: 0  total_candidates  high_scorers_137  high_scorers_500  \
# count    607.000000        607.000000        607.000000        607.000000
# mean   23940.336079        560.032949        424.166392         96.088962
# std    11480.748052        221.180538        167.879859         49.580837
# min        0.000000        158.000000        129.000000         43.000000
# 25%    26304.500000        424.000000        325.500000         63.000000
# 50%    28149.000000        498.000000        394.000000         84.000000
# 75%    31661.000000        642.000000        494.000000        113.500000
# max    32801.000000       1968.000000       1732.000000        594.000000
#
#        high_scorers_700  Success rate
# count        607.000000    607.000000
# mean           1.009885     75.988802
# std            1.258595      5.275453
# min            0.000000     70.019724
# 25%            0.000000     71.631194
# 50%            1.000000     74.170274
# 75%            2.000000     79.688140
# max            9.000000     89.635854

# %%
print('Info of data with excluding suspected centers.')

df_2.describe()
# Out:
# Info of data with excluding suspected centers.
#          Unnamed: 0  total_candidates  high_scorers  high_scorers_500  \
# count  32118.000000      32118.000000  32118.000000      32118.000000
# mean   16239.486238      17873.406096    312.937356         46.457687
# std     9358.885802       8827.869256    174.963557         35.031356
# min        1.000000          9.000000      6.000000          0.000000
# 25%     8157.250000       9507.000000    184.000000         18.000000
# 50%    16199.500000      19783.000000    310.000000         39.000000
# 75%    24228.750000      25779.000000    415.000000         67.000000
# max    32807.000000      25779.000000   1619.000000        324.000000
#
#        high_scorers_700  Success rate
# count      32118.000000  32118.000000
# mean           1.379413      7.986031
# std            0.803138     16.723883
# min            0.000000      0.237578
# 25%            1.000000      0.950386
# 50%            1.000000      1.683541
# 75%            2.000000      2.835641
# max            6.000000     70.000000

# %%
print('Info of data with including suspected centers.')
df_3.describe()
# Out:
# Info of data with including suspected centers.
#          Unnamed: 0  total_candidates  high_scorers  high_scorers_500  \
# count  32808.000000      32808.000000  32808.000000      32808.000000
# mean   16403.500000      17508.631645    314.764478         47.338606
# std     9470.998152       9082.243797    175.350242         35.949160
# min        0.000000          9.000000      6.000000          0.000000
# 25%     8201.750000       9507.000000    187.000000         18.000000
# 50%    16403.500000      19783.000000    310.000000         40.000000
# 75%    24605.250000      25779.000000    421.000000         67.000000
# max    32807.000000      25779.000000   1732.000000        594.000000
#
#        high_scorers_700  Success rate
# count      32808.000000  32808.000000
# mean           1.369605      9.409272
# std            0.816773     19.200101
# min            0.000000      0.237578
# 25%            1.000000      0.965902
# 50%            1.000000      1.726211
# 75%            2.000000      3.093565
# max            9.000000     89.635854

# %% [markdown]
# ## AS per the above information we can see that the suspected centers have increased the deviation of success rate by 3 units which is a lot because the total number of centers are 32808 and suspected centers are only 607 this signifies that there is some kind of anamolies in the 607 centers.

# %% [markdown]
# ## Point to be noted -
#
# - The suspected centers that are filtered has success rate > 70% (The threshold (70%) can be changed according to the decision)
# - Assumed cutoff marks - 136
# - The Success rate feature is the % of students from given center that has qualified the cutoff marks

# %% [markdown]
# ## From the above data analysis we can conclude that there are many centers that are suspected for the paper leak and some centers have students with extremely high perfomance which is unreal as compared to the students which are from non suspected centers.
#
# - The suggestion can be that the a re examination of the suspected centers should be conducted in order to re-check the ability of the students with abnormal scores.
# - The threshold of the success rate can be adjusted according to needs in this data threshold = 70%.

# %% [markdown]
# # Data Analysis Report: Exam Centers Performance
#
# ## Key Findings
#
# ### Success Rate Discrepancies
# There is a significant difference in the success rates between students from suspected and non-suspected centers.
#
# - **Example 1: Bhavnagar, Gujarat**
#   - **Center**: Amarjyoti Saraswati International School Kalvibid
#   - **Candidates Appearing**: 359
#   - **Successful Candidates**: 311
#   - **Exceptional Scores**: No students scored over 700 marks
#   - **Observation**: High success rate despite no exceptionally high scores raises concerns.
#
# - **Example 2: Sikar, Rajasthan**
#   - **Center**: Aryan PG College
#   - **Candidates Appearing**: 501
#   - **Successful Candidates**: 433
#   - **Exceptional Scores**: 5 students scored over 700 marks
#   - **Observation**: High success rate with a few exceptionally high scores, suggesting potential irregularities.
#
# - **Example 3: Sikar, Rajasthan**
#   - **Center**: Asha Academy
#   - **Candidates Appearing**: 355
#   - **Successful Candidates**: 302
#   - **Exceptional Scores**: 2 students scored over 700 marks
#   - **Observation**: Similar pattern of high success rate with some exceptionally high scores.
#
# - **Example 4: Sikar, Rajasthan**
#   - **Center**: Bhartiya Mahila P.G. Mahavidyalaya
#   - **Candidates Appearing**: 500
#   - **Successful Candidates**: 433
#   - **Exceptional Scores**: 3 students scored over 700 marks
#   - **Observation**: High success rate with a few exceptionally high scores, suggesting potential irregularities.
#
# - **Example 5: Vijayawada, Andhra Pradesh**
#   - **Center**: Bhashyam (E.M) High School
#   - **Candidates Appearing**: 499
#   - **Successful Candidates**: 440
#   - **Exceptional Scores**: 1 student scored over 700 marks
#   - **Observation**: Exceptionally high success rate with very few high scores.
#
# ### Comparison and Discrepancies
# The average success rate of suspected centers is 75% higher than that of non-suspected centers. This difference is significant and suggests that the results from suspected centers are disproportionately high compared to their counterparts.
#
# Additionally, the suspected centers have increased the deviation of the success rate by 3 units. Considering the total number of centers is 32,808 and the number of suspected centers is only 607, this signifies that there are anomalies in these 607 centers.
#
# ## Recommendations
#
# ### Re-Examine Suspected Centers
# - **Action**: Conduct thorough re-examinations at suspected centers to verify the authenticity of the results.
# - **Objective**: Ensure that unusually high scores are legitimate and address any discrepancies.
#
# ### Adjust Success Rate Threshold
# - **Action**: Set a new threshold of 70% for success rates to better identify abnormal performance patterns.
# - **Objective**: Align with realistic expectations and improve the accuracy of performance assessments.
#
# ## Implementation Steps
#
# ### Re-Examination
# - Validate the results from suspected centers, especially those with unusually high success rates.
# - Document findings and implement corrective measures as necessary.
#
# ### Threshold Adjustment
# - Apply the new 70% success rate threshold and re-analyze the data.
# - Monitor and adjust as needed to maintain fairness and accuracy in performance evaluation.
#
# ## Conclusion
# The analysis reveals significant discrepkeeping the threshold of the success rate 70% we have divided the centers into suspected and non suspectedancies in success rates between suspected and non-suspected centers, suggesting potential irregularities. Re-examination and threshold adjustmaccording to our analysis there are 607 most of them including center in west region of India centers where the re examination should be proceededsfor  are crucial to ensure the integrity of the examination process and accurate assessment of student performance.
# amination process and accurate assessment of student performance.

# %%
x1 = df_1[df_1['Success rate']>85]
x1.to_csv('neet most suspected.csv')
